# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
potato = pd.read_csv('../data/potato.csv')
leaf = pd.read_csv('../data/leaf.csv')
garlic = pd.read_csv('../data/garlic.csv')
s_potato = pd.read_csv('../data/s_potato.csv')

# %%
p5 =potato[-1718:-494]
l5 = leaf[-1718:-494]
g5 = garlic[-1718:-494]
s5 = s_potato[-1718:-494]

p3 =potato[-1227:-494]
l3 = leaf[-1227:-494]
g3 = garlic[-1227:-494]
s3 = s_potato[-1227:-494]

p2 =potato[-981:-494]
l2 = leaf[-981:-494]
g2 = garlic[-981:-494]
s2 = s_potato[-981:-494]

# %%
p3
# Out:
#       Unnamed: 0         YMD      YM    MD Product        Price  KRW_USD_EXR  \
# 2743       10683  2016-01-04  201601   104      감자  5004.400000       1208.5
# 2744       10684  2016-01-05  201601   105      감자  5004.400000       1208.5
# 2745       10685  2016-01-06  201601   106      감자  4948.431373       1208.5
# 2746       10686  2016-01-07  201601   107      감자  5028.490196       1208.5
# 2747       10687  2016-01-08  201601   108      감자  5027.509804       1208.5
# ...          ...         ...     ...   ...     ...          ...          ...
# 3471       11411  2018-12-24  201812  1224      감자  6866.800000       1118.1
# 3472       11412  2018-12-26  201812  1226      감자  7102.590909       1118.1
# 3473       11413  2018-12-27  201812  1227      감자  7140.140625       1118.1
# 3474       11414  2018-12-28  201812  1228      감자  6640.712121       1118.1
# 3475       11415  2018-12-31  201812  1231      감자  6979.421875       1118.1
#
# ...

# %%
xlabels = ['2017-01-02''2017-07-04','2017-12-02','2018-01-02','2018-06-02','2018-12-03']

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
plt.plot(p2['YMD'], p2['Price'], label='Price')
plt.plot(p2['YMD'], p2['30mv'], label='30mv')
plt.plot(p2['YMD'], p2['60mv'], label='60mv')
plt.plot(p2['YMD'], p2['90mv'], label='90mv')
plt.plot(p2['YMD'], p2['120mv'], label='120mv')
ax.xaxis.set_major_locator(ticker.MultipleLocator(60))
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
plt.plot(g2['YMD'], g2['Price'], label='Price')
plt.plot(g2['YMD'], g2['30mv'], label='30mv')
plt.plot(g2['YMD'], g2['60mv'], label='60mv')
plt.plot(g2['YMD'], g2['90mv'], label='90mv')
plt.plot(g2['YMD'], g2['120mv'], label='120mv')
ax.xaxis.set_major_locator(ticker.MultipleLocator(60))
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
plt.plot(s2['YMD'], s2['Price'], label='Price')
plt.plot(s2['YMD'], s2['30mv'], label='30mv')
plt.plot(s2['YMD'], s2['60mv'], label='60mv')
plt.plot(s2['YMD'], s2['90mv'], label='90mv')
plt.plot(s2['YMD'], s2['120mv'], label='120mv')
ax.xaxis.set_major_locator(ticker.MultipleLocator(60))
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
plt.plot(l2['YMD'], l2['Price'], label='Price')
plt.plot(l2['YMD'], l2['30mv'], label='30mv')
plt.plot(l2['YMD'], l2['60mv'], label='60mv')
plt.plot(l2['YMD'], l2['90mv'], label='90mv')
plt.plot(l2['YMD'], l2['120mv'], label='120mv')
ax.xaxis.set_major_locator(ticker.MultipleLocator(60))
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.plot(p3['YMD'], p3['Price'], label='Price')
plt.plot(p3['YMD'], p3['30mv'], label='30mv')
plt.plot(p3['YMD'], p3['60mv'], label='60mv')
plt.plot(p3['YMD'], p3['90mv'], label='90mv')
plt.plot(p3['YMD'], p3['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.plot(g3['YMD'], g3['Price'], label='Price')
plt.plot(g3['YMD'], g3['30mv'], label='30mv')
plt.plot(g3['YMD'], g3['60mv'], label='60mv')
plt.plot(g3['YMD'], g3['90mv'], label='90mv')
plt.plot(g3['YMD'], g3['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.plot(g3['YMD'], g3['Price'], label='Price')
plt.plot(g3['YMD'], g3['30mv'], label='30mv')
plt.plot(g3['YMD'], g3['60mv'], label='60mv')
plt.plot(g3['YMD'], g3['90mv'], label='90mv')
plt.plot(g3['YMD'], g3['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.plot(s3['YMD'], s3['Price'], label='Price')
plt.plot(s3['YMD'], s3['30mv'], label='30mv')
plt.plot(s3['YMD'], s3['60mv'], label='60mv')
plt.plot(s3['YMD'], s3['90mv'], label='90mv')
plt.plot(s3['YMD'], s3['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.plot(l3['YMD'], l3['Price'], label='Price')
plt.plot(l3['YMD'], l3['30mv'], label='30mv')
plt.plot(l3['YMD'], l3['60mv'], label='60mv')
plt.plot(l3['YMD'], l3['90mv'], label='90mv')
plt.plot(l3['YMD'], l3['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(150))
plt.plot(p5['YMD'], p5['Price'], label='Price')
plt.plot(p5['YMD'], p5['30mv'], label='30mv')
plt.plot(p5['YMD'], p5['60mv'], label='60mv')
plt.plot(p5['YMD'], p5['90mv'], label='90mv')
plt.plot(p5['YMD'], p5['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(150))
plt.plot(g5['YMD'], g5['Price'], label='Price')
plt.plot(g5['YMD'], g5['30mv'], label='30mv')
plt.plot(g5['YMD'], g5['60mv'], label='60mv')
plt.plot(g5['YMD'], g5['90mv'], label='90mv')
plt.plot(g5['YMD'], g5['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(150))
plt.plot(s5['YMD'], s5['Price'], label='Price')
plt.plot(s5['YMD'], s5['30mv'], label='30mv')
plt.plot(s5['YMD'], s5['60mv'], label='60mv')
plt.plot(s5['YMD'], s5['90mv'], label='90mv')
plt.plot(s5['YMD'], s5['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(150))
plt.plot(l5['YMD'], l5['Price'], label='Price')
plt.plot(l5['YMD'], l5['30mv'], label='30mv')
plt.plot(l5['YMD'], l5['60mv'], label='60mv')
plt.plot(l5['YMD'], l5['90mv'], label='90mv')
plt.plot(l5['YMD'], l5['120mv'], label='120mv')
plt.grid()
plt.legend()
plt.show()
